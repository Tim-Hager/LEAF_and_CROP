# %% [markdown]
# # Analysis of the UjiIndoorLoc dataset

# %% [markdown]
# ## Imports

# %%
#!pip install -q pandas
import pandas as pd

# %% [markdown]
# ## Read dataset

# %%
# Simple configuration
DATA_PATH = '/Users/timhager/Library/Mobile Documents/com~apple~CloudDocs/Masterstudium/Auslandssemester/IACOMM/Trabajo_final/dataset/Crop_recommendation.csv'

# %%
data = pd.read_csv(DATA_PATH)

# Remove unnecessary columns
drop_columns = []
data = data.drop(columns=drop_columns)

# %% [markdown]
# ## First analysis for better overview

# %%
# Shapes
print("Training data shape:", data.shape)

print()

# Heads
print("Data head:")
print(data.head())

print()

# Info
print("Data info:")
print(data.info())

print()

# Number classes
print("Number of classes:", data['label'].nunique())

# Every class label
print("Class labels:", data['label'].unique())

print()

# Describe
print("Data description:")
print(data.describe())

print()

# Check for NaN and Null
print("Data NaN values:")
print(data.isna().sum())

print()

# Check for duplicates
print("Data duplicate rows:", data.duplicated().sum())
# Out:
# Training data shape: (2200, 8)
#
# Data head:
#     N   P   K  temperature   humidity        ph    rainfall label
# 0  90  42  43    20.879744  82.002744  6.502985  202.935536  rice
# 1  85  58  41    21.770462  80.319644  7.038096  226.655537  rice
# 2  60  55  44    23.004459  82.320763  7.840207  263.964248  rice
# 3  74  35  40    26.491096  80.158363  6.980401  242.864034  rice
# 4  78  42  42    20.130175  81.604873  7.628473  262.717340  rice
#
# Data info:
# <class 'pandas.DataFrame'>
# RangeIndex: 2200 entries, 0 to 2199
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   N            2200 non-null   int64
#  1   P            2200 non-null   int64
#  2   K            2200 non-null   int64
#  3   temperature  2200 non-null   float64
#  4   humidity     2200 non-null   float64
#  5   ph           2200 non-null   float64
#  6   rainfall     2200 non-null   float64
#  7   label        2200 non-null   str
# ...
